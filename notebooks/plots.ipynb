# %%
baseline_fid = [(200,6.2973), (250,6.0200), (300,5.8460), (350,5.7242), (400,5.7550), (450,5.6589), (500,5.6684)]
sharedeps_fid = [(100,5.9616), (200,5.4461), (250,5.2676)]  #100,200, 250

# %%
import matplotlib.pyplot as plt

# Extract x and y values from the tuples
baseline_x = [x for x, y in baseline_fid]
baseline_y = [y for x, y in baseline_fid]
sharedeps_x = [x for x, y in sharedeps_fid]
sharedeps_y = [y for x, y in sharedeps_fid]

# Create the plot
plt.figure(figsize=(10, 6))
plt.plot(baseline_x, baseline_y, marker='o', label='Baseline FID', linewidth=2)
plt.plot(sharedeps_x, sharedeps_y, marker='s', label='SharedEPS FID', linewidth=2)

plt.xlabel('Epoch')
plt.ylabel('FID Score')
plt.title('FID Score Comparison: Baseline vs SharedEPS')
plt.legend()
plt.grid(True, alpha=0.3)
plt.tight_layout()
plt.show()
